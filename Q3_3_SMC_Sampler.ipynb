# %% [markdown]
# # SMC sampler PRC-ABC algorithm (Peters et al., 2009)
#
# Dans cette partie nous avons essayé de mettre en place le sampler décrit dans l'Annexe A de notre article. Il est basé sur à la fois sur la technique du Sequential Monte Carlo et sur la Partial Rejection.
#
# Remarque : Comme nous avons pas obtenus de résultats satisfaisants ce code contient volontairement quelques "print" supplémentaires pour que le correcteur puisse identifier plus facilement
# ce qui marche ou pas.
#
# Tout le code est rapide à exécuter sauf la cellule qui fait tourner l’algorithme, elle sera indiquée comme telle.

# %%
import numpy as np
from scipy.stats import levy_stable
from scipy.stats import uniform
from scipy.stats import multivariate_normal

# %% [markdown]
# On va maintenant définir des fonctions qui nous seront utiles par la suite:

# %%
def prior_sample():
    # Sample from prior distribution
    # For univariate alpha-stable models, sample each parameter from its respective uniform distribution
    alpha = uniform.rvs(1.1, 0.9)  # U[1.1, 2]
    beta = uniform.rvs(-1, 2)  # U[-1, 1]
    gamma = uniform.rvs(0, 300)  # U[0, 300]
    delta = uniform.rvs(-300, 600)  # U[-300, 300]
    return [alpha, beta, gamma, delta]

# %%
def univ_alpha_stable_sampler(params,size,seed) :
    """
    Applies the sampling algoritm from the article for alpha-stable distributions

    Args:
        params (list): parameters of the alpha stable distribution (alpha,beta,gamma,delta)
        size (int): sample size
        seed (int): for reproducibility

    Returns:
        np.array : n samples from the alpha stable 
    """
    alpha,beta,gamma,delta = params[0],params[1],params[2],params[3]
    y_bar = 0
    np.random.seed(seed)
    w = np.random.standard_exponential(size=size)
    u = np.random.uniform(low = -np.pi/2, high = np.pi/2, size = size)
    if alpha == 1 :
        y_bar = 2/np.pi*((np.pi/2+beta*u)*np.tan(u)-beta*np.log((np.pi/2*w*np.cos(u))/(np.pi/2+beta*u)))
        return gamma*y_bar + delta
    else :
        S = (1+beta**2*np.tan(np.pi*alpha/2)**2)**(1/(2*alpha))
        B = 1/alpha*np.arctan(beta*np.tan(np.pi*alpha/2))
        y_bar = (S*(np.sin(alpha)*(u+B))*(np.cos(u-alpha*(u+B))/w)**((1-alpha)/alpha))/np.cos(u)**(1/alpha)
        return gamma*y_bar + delta

# %%
def compute_quantiles(data):
    # Compute quantile-based summary statistics
    quantiles = np.percentile(data, [5, 25, 50, 75, 95])
    v_alpha = (quantiles[4] - quantiles[0]) / (quantiles[3] - quantiles[1])
    v_beta = (quantiles[4] + quantiles[0] - 2 * quantiles[2]) / (quantiles[4] - quantiles[0])
    v_gamma = (quantiles[3] - quantiles[1]) / quantiles[2]
    return v_alpha, v_beta, v_gamma

# %%
def S(data):
    # Compute summary statistics of the data
    # This function should return low-dimensional summary statistics S(data)
    v_alpha, v_beta, v_gamma = compute_quantiles(data)
    mean_x = np.mean(data)
    return np.array([v_alpha, v_beta, v_gamma, mean_x])

# %%
def psi(y, x, covariance = np.diag([0.25,0.25,1,1])):
    # Define smoothing kernel using a Gaussian kernel with estimated covariance
    return multivariate_normal.pdf(y, mean=x, cov=covariance)

# %%
def cov_estimate(theta_hat,n_draws = 1000):
    x = np.array([univ_alpha_stable_sampler(params = theta_hat, size = 200, seed=None) for _ in range(n_draws)])
    sumary_statistics = np.array([S(x_i) for x_i in x])

    return np.cov(sumary_statistics, rowvar=False)

# %%
def norm2(u) :
    # compute the norm 2 of a vector
    return np.sqrt(np.sum(u*u))

# %%
def K(u, sigma) :
    # Define a Gaussian Kernel in the dimension of S(.)
    d = 4
    return np.exp(-(u.T@np.linalg.inv(sigma)@u)/2)/(np.sqrt(2*np.pi)**d*np.sqrt(np.linalg.det(sigma)))

# %%
def resample(theta, weights,N) :
    # to resample with respect to the weights
    
    normalized_weights = weights['t']/np.sum(weights['t'])
    print(theta['t-1'].shape)
    new_indices = np.random.choice(range(N),replace=True, p=normalized_weights)
    theta['t'] = theta['t'][new_indices]

    weights['t'] = np.ones(N)/N

# %%
def sample_from_M_t(N, theta_prev, weights_prev):
    """sample theta_i from M_t(theta_i)

    Args:
        N (int): nb of particles
        theta_prev (np.array of size N): thetas rom the previous time step
        weights_prev (np.array of size N): weights from the previous time step

    Returns:
        a theta [alpha, beta, gamma, delta]
    """

    normalized_weights = weights_prev/np.sum(weights_prev)
    # Choose a component based on the weights
    component = np.random.choice(range(N), p=normalized_weights)
    # Generate a sample from the chosen component
    sample = np.random.multivariate_normal(mean = theta_prev[component], cov = np.diag([0.25,0.25,1,1]))
    
    return sample

# %%
def M_t(N,theta_i,theta_prev, weights_prev) :
    # defines the mutation kernel M_t as the weighted sum of densities
    
    densities = np.array([ psi(theta_i, theta_prev[i]) for i in range(N)])
    return np.sum(weights_prev*densities)

# %%
def normalize(u) :
    # normalize a vector u (sum of coordinates equals 1)
    return u/np.sum(u)

# %%
def prior_density(theta_i) :
    # return the product of the uniform prior densities evaluated respectively in alpha, beta, gamma, delta

    alpha,beta,gamma,delta = theta_i[0],theta_i[1],theta_i[2],theta_i[3]
    
    return uniform.pdf(alpha,1.1,0.9)*uniform.pdf(beta,-1,2)*uniform.pdf(gamma,0,300)*uniform.pdf(delta,-300,600)

# %%
def initialization(T=10,N =1000,n=200,covariance = np.diag([0.25, 0.25, 1, 1]), seed=124) :
    """ Initialize the algorithm  

    Args:
        T (int, optional): number of time steps. Defaults to 10.
        N (int, optional): number of particles. Defaults to 1000.
        n (int, optional): length of y and x. Defaults to 200.
        covariance (np.array, optional): lambda in the paper. Defaults to np.diag([0.25, 0.25, 1, 1]).
        seed (int, optional): to init the RNG for reproducibility. Defaults to 124.

    Returns:    y ( np.array of size n) : "observed" data.
                x (np.array of size n) : auxiliary data simulated from theta_i.
                theta (dict) : stores the N thetas at time t and t-1 with (2 keys).
                weights (dict) : stores the N weigths at time t and t-1 with (2 keys).
                sigma_hat (4x4 np.array) : covariance matrix of S(x) 
        
    """
    # Tolerance schedule
    epsilons = [k for k in range(1000,100, -100)]+[k for k in range(100,9, -1)] + [k+0.5 for k in range(9,4,-1)] + [5-k*0.05 for k in range(40)]+[3-0.01*k for k in range(301)]  
    epsilon = epsilons[0]
    
    # generate the "observed data" y :
    levy_stable.parameterization = 'S0'
    y = levy_stable.rvs(1.7, 0.9, loc=10, scale=10, size=200)
    
    # estimate sigma_hat :
    sigma_hat = cov_estimate(np.array([1.7,0.9,10,10]))
    print("sigma_hat :\n", sigma_hat)
    print('det(sigma_hat) = ', np.linalg.det(sigma_hat))
    
    # Sample theta from the prior : 
        # theta is a Nx4 matrix containing all the N theta_i
    initial_theta = np.array([prior_sample() for _ in range(N)])
    theta = {"t" : initial_theta , "t-1" :initial_theta }
    print('theta["t"] = ',np.round(theta['t'][:5],4))
    
   # generate the x 
    x = np.array([levy_stable.rvs(theta['t'][i][0], theta['t'][i][1], loc=theta['t'][i][3], scale=theta['t'][i][2], size=200) for i in range(N)])
    print('x.shape = ',x.shape) 
    
    # set weights their initial values :
    initial_weights = np.array([K((S(y)-S(x[i]))/epsilon,(epsilon**2)*sigma_hat)/epsilon for i in range(N)])
    print("weights = ", initial_weights)

    weights = {"t" : initial_weights, "t-1" : initial_weights}
    
    return y,x,theta,weights,sigma_hat

# %% [markdown]
# ### Remarque :
# Il n'est pas précisé dans l'article si les poids $ W^{i}_t(\theta^{i}_t) $ doivent sommer à 1 pour $i = 1...N$. Donc on ne l'a pas fait...

# %% [markdown]
# Initialisation des paramètres :

# %%
arg = initialization()
# Out:
# sigma_hat :
#  [[ 2.53860936e+00 -1.22821067e-01 -1.30866612e-01 -6.99933804e+00]
#  [-1.22821067e-01  2.26316622e-02 -2.04722122e-02  1.00018299e+00]
#  [-1.30866612e-01 -2.04722122e-02  2.60621022e-01 -2.17568715e+00]
#  [-6.99933804e+00  1.00018299e+00 -2.17568715e+00  8.15704477e+02]]
# det(sigma_hat) =  6.787464192209966
# theta["t"] =  [[ 1.536400e+00  3.197000e-01  6.602770e+01  1.639823e+02]
#  [ 1.935200e+00  1.326000e-01  1.184304e+02  5.319600e+01]
#  [ 1.880000e+00 -1.671000e-01  1.009823e+02  2.194340e+01]
#  [ 1.572100e+00  1.434000e-01  1.823109e+02  3.775380e+01]
#  [ 1.603900e+00  6.450000e-01  7.207700e+00 -2.047916e+02]]
# x.shape =  (1000, 200)
# weights =  [9.72269109e-18 9.72269109e-18 9.72269045e-18 9.72269102e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269108e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269108e-18 9.72269109e-18 9.72269108e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269108e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269108e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269095e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269108e-18
#  9.72269109e-18 9.72269109e-18 9.72269099e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269107e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269023e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269074e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269106e-18 9.72269107e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269108e-18 9.72269109e-18 9.72269108e-18 9.72269109e-18
#  9.72269035e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269102e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269108e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269108e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269108e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269108e-18 9.72269107e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72268989e-18 9.72269109e-18 9.72269109e-18
#  9.72269102e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269107e-18 9.72269099e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269108e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269107e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72268941e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269107e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269108e-18 9.72269108e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269107e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269098e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269108e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269105e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269106e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269108e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269101e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269107e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269106e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269108e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269107e-18 9.72269109e-18 9.72269108e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269108e-18 9.72268882e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269108e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269070e-18 9.72269109e-18 9.72269109e-18
#  9.72269048e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269108e-18
#  9.72269108e-18 9.72269109e-18 9.72269106e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269094e-18 9.72269109e-18 9.72269094e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72268891e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269108e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269107e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269107e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72266620e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269105e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269108e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269104e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72268999e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18
#  9.72269109e-18 9.72269109e-18 9.72269109e-18 9.72269109e-18]

# %% [markdown]
# Nous arrivons maintenant à l'application de l'algorithme SMC en lui même :

# %% [markdown]
# ### Atention la cellule suivante prend du temps à s'éxécuter.

# %%
N =1000
n=200
covariance = np.diag([0.25, 0.25, 1, 1])
seed=124

# Tolerance schedule
epsilons = [k for k in range(1000,100, -100)]+[k for k in range(100,9, -1)] + [k+0.5 for k in range(9,4,-1)] + [5-k*0.05 for k in range(40)]+[3-0.01*k for k in range(301)]  
T = len(epsilons)
levy_stable.parameterization = 'S0'

# get the values of y,x,theta,weights,sigma_hat from the initialisation function :
y,x,theta,weights,sigma_hat = arg

#set t = 2
t=2

# to store the theta['t'] and the weights['t'] for t = 1...T :
res = [[theta['t'],weights['t']]]

while t<T :
    print("t = ",t)

    # update the tolerance parameter epsilon_t : 
    epsilon = epsilons[t]
    print("epsilon = ",epsilon)
    
    # store the values of the thetas and the weights to update theta['t-1] and weights['t-1] later :
    theta_maj = theta['t']
    weights_maj = weights['t']
    
    i = 0 
    
    # dynamic thresehold : 
    c_t = np.quantile(weights['t'], 0.9) 

    while i<N : 
        print('###########    i = ',i)

        #----------Mutation and correction : 
        
        # sample theta_i from M_t(theta_i) :
        theta['t'][i] = sample_from_M_t(N, theta['t-1'], weights['t-1'])
        
        # sometimes the values sampled for one of the 4 component of theta_i is out of the prior
        # so we draw another thetha_i : 
        if prior_density(theta['t'][i])==0:
            print("the prior is O")
            continue
        # Draw x_i from p(x_i/theta_i) :
        x[i] = levy_stable.rvs(theta['t'][i][0], theta['t'][i][1], loc=theta['t'][i][3], scale=theta['t'][i][2], size=200)
        print(f'theta["t"][{i}]= ',theta['t'][i])

        # Update the weight of theta_i :
        weights['t'][i] = (K((S(y)-S(x[i]))/epsilon,(epsilon**2)*sigma_hat)/epsilon)*prior_density(theta['t'][i])/M_t(N,theta['t'][i],theta['t-1'],weights['t-1'])
        
        # Draw uniformly a random value between 0 and 1 :

        u = np.random.uniform(low=0, high=1)

        print("rapport W_i/c_t = ", weights['t'][i]/c_t)
        
        # compute the probability for theta_i to be rejected :
        proba = 1-np.minimum(1,weights['t']/c_t)
        
        print("c_t = ", c_t)
        print(f"weights['t'][{i}] = ", weights['t'][i])
        print('sum(weights) = ', np.sum(weights['t']))
        print(f'proba[{i}] = ', proba[i])

        if u<=proba[i] :
            #---Rejection : 
            print(f"theta['t'][{i}] = {np.round(theta['t'][i],3)} rejected !")
            continue
        else : 
            #---Acceptance
            print(f"theta['t'][{i}] = {np.round(theta['t'][i],3)} accepted !")
            # update the weights :
            weights['t'][i] = weights['t'][i]/(1-proba[i])
            # go to the next theta_i
            i = i+1
    
    t+=1
    # update the values 
    theta['t-1'],weights['t-1'] = theta_maj,weights_maj
    # update the results
    res.append((theta['t'], weights['t']))

    # We didn't understood well the resampling part, but according to "On sequential Monte Carlo, partial rejection control and approximate Bayesian computation"
    # G. W. Peters∗† Y. Fan∗ S. A. Sisson∗‡ November 11, 2009, this step is not always necessary...so didn't implement it truly
    """
    # Resample : 
    weights['t'] = np.ones(N)/N
    weights['t-1'] = np.ones(N)/N
    """
# Out:
# t =  2
# epsilon =  800
# ###########    i =  0
# the prior is O
# ###########    i =  0
# the prior is O
# ###########    i =  0
# the prior is O
# ###########    i =  0
# the prior is O
# ###########    i =  0
# the prior is O
# ###########    i =  0
# theta["t"][0]=  [   1.41853568   -0.41939725  258.53871005 -283.98570557]
# rapport W_i/c_t =  6208891733799.296
# c_t =  9.722691090319275e-18
# weights['t'][0] =  6.036713634096741e-05
# sum(weights) =  6.036713635068039e-05
# proba[0] =  0.0
# theta['t'][0] = [   1.419   -0.419  258.539 -283.986] accepted !
# ###########    i =  1
# the prior is O
# ###########    i =  1
# theta["t"][1]=  [   1.38888102   -0.29351317  256.68270957 -284.30619862]
# rapport W_i/c_t =  9.383226057365928
# c_t =  9.722691090319275e-18
# weights['t'][1] =  9.123020838640335e-17
# sum(weights) =  6.03671363507619e-05
# proba[1] =  0.0
# theta['t'][1] = [   1.389   -0.294  256.683 -284.306] accepted !
# ###########    i =  2
# theta["t"][2]=  [   1.57885716   -0.6250183   258.88922619 -283.59285124]
# rapport W_i/c_t =  2.0264965360163933
# c_t =  9.722691090319275e-18
# weights['t'][2] =  1.970299981528946e-17
# sum(weights) =  6.036713635077188e-05
# proba[2] =  0.0
# theta['t'][2] = [   1.579   -0.625  258.889 -283.593] accepted !
# ###########    i =  3
# theta["t"][3]=  [ 1.79492558e+00 -2.01585510e-01  2.58727840e+02 -2.85898459e+02]
# rapport W_i/c_t =  14.25581247279638
# c_t =  9.722691090319275e-18
# weights['t'][3] =  1.3860486091451975e-16
# sum(weights) =  6.0367136350900765e-05
# proba[3] =  0.0
# theta['t'][3] = [ 1.79500e+00 -2.02000e-01  2.58728e+02 -2.85898e+02] accepted !
# ###########    i =  4
# the prior is O
# ###########    i =  4
# theta["t"][4]=  [   1.31412299   -0.28988079  258.03728253 -282.93690071]
# rapport W_i/c_t =  3.198903467254246
# c_t =  9.722691090319275e-18
# weights['t'][4] =  3.110195023986429e-17
# sum(weights) =  6.0367136350922144e-05
# proba[4] =  0.0
# theta['t'][4] = [   1.314   -0.29   258.037 -282.937] accepted !
# ###########    i =  5
# theta["t"][5]=  [   1.33801922   -0.76949545  260.03731058 -283.16912755]
# rapport W_i/c_t =  8.551864475417224
# c_t =  9.722691090319275e-18
# weights['t'][5] =  8.314713654075696e-17
# sum(weights) =  6.036713635099557e-05
# proba[5] =  0.0
# theta['t'][5] = [   1.338   -0.769  260.037 -283.169] accepted !
# ###########    i =  6
# the prior is O
# ###########    i =  6
# theta["t"][6]=  [   1.11792169   -0.68977265  258.23903646 -282.99903909]
# rapport W_i/c_t =  3.6340407751828576
# c_t =  9.722691090319275e-18
# weights['t'][6] =  3.533265586672732e-17
# sum(weights) =  6.036713635102118e-05
# proba[6] =  0.0
# theta['t'][6] = [   1.118   -0.69   258.239 -282.999] accepted !
# ###########    i =  7
# the prior is O
# ###########    i =  7
# the prior is O
# ###########    i =  7
# theta["t"][7]=  [ 1.19106161e+00 -1.88508306e-01  2.59541184e+02 -2.82653365e+02]
# rapport W_i/c_t =  7.628535778869883
# c_t =  9.722691090319275e-18
# weights['t'][7] =  7.416989684940002e-17
# sum(weights) =  6.036713635108563e-05
# proba[7] =  0.0
# theta['t'][7] = [ 1.19100e+00 -1.89000e-01  2.59541e+02 -2.82653e+02] accepted !
# ###########    i =  8
# the prior is O
# ###########    i =  8
# theta["t"][8]=  [   1.35194609    0.43204396  258.99505982 -283.62948696]
# rapport W_i/c_t =  7.831001978468997
# c_t =  9.722691090319275e-18
# weights['t'][8] =  7.613841316433313e-17
# sum(weights) =  6.036713635115204e-05
# proba[8] =  0.0
# theta['t'][8] = [   1.352    0.432  258.995 -283.629] accepted !
# ###########    i =  9
# theta["t"][9]=  [   1.47515946   -0.91581685  258.46790302 -284.17151548]
# rapport W_i/c_t =  2.5877563881396264
# c_t =  9.722691090319275e-18
# weights['t'][9] =  2.515995597888193e-17
# sum(weights) =  6.036713635116748e-05
# proba[9] =  0.0
# theta['t'][9] = [   1.475   -0.916  258.468 -284.172] accepted !
# ###########    i =  10
# theta["t"][10]=  [ 1.63429945e+00  1.60035422e-01  2.58834792e+02 -2.82830757e+02]
# rapport W_i/c_t =  6.733679426893234
# c_t =  9.722691090319275e-18
# weights['t'][10] =  6.546948496892105e-17
# sum(weights) =  6.0367136351223227e-05
# proba[10] =  0.0
# theta['t'][10] = [ 1.63400e+00  1.60000e-01  2.58835e+02 -2.82831e+02] accepted !
# ###########    i =  11
# theta["t"][11]=  [ 1.68593300e+00 -2.70287976e-01  2.58033331e+02 -2.84240231e+02]
# rapport W_i/c_t =  2.1799676377585966
# c_t =  9.722691090319275e-18
# weights['t'][11] =  2.1195151928819862e-17
# sum(weights) =  6.03671363512347e-05
# proba[11] =  0.0
# theta['t'][11] = [ 1.68600e+00 -2.70000e-01  2.58033e+02 -2.84240e+02] accepted !
# ###########    i =  12
# theta["t"][12]=  [   1.52413447   -0.31328923  257.18179751 -283.72133848]
# rapport W_i/c_t =  4.187547641051798
# c_t =  9.722691090319275e-18
# weights['t'][12] =  4.071423213994181e-17
# sum(weights) =  6.036713635126569e-05
# proba[12] =  0.0
# theta['t'][12] = [   1.524   -0.313  257.182 -283.721] accepted !
# ###########    i =  13
# theta["t"][13]=  [   1.1396892    -0.34282336  257.3202646  -282.25724648]
# rapport W_i/c_t =  17.031632527790777
# c_t =  9.722691090319275e-18
# weights['t'][13] =  1.6559330183154335e-16
# sum(weights) =  6.036713635142156e-05
# proba[13] =  0.0
# theta['t'][13] = [   1.14    -0.343  257.32  -282.257] accepted !
# ###########    i =  14
# theta["t"][14]=  [   1.78585572   -0.46750968  257.83578236 -284.19001341]
# rapport W_i/c_t =  2.6489056429544675
# c_t =  9.722691090319275e-18
# weights['t'][14] =  2.575449129384985e-17
# sum(weights) =  6.036713635143759e-05
# proba[14] =  0.0
# theta['t'][14] = [   1.786   -0.468  257.836 -284.19 ] accepted !
# ###########    i =  15
# the prior is O
# ###########    i =  15
# theta["t"][15]=  [ 1.45182693e+00 -1.99711888e-01  2.59167815e+02 -2.83041679e+02]
# rapport W_i/c_t =  3.2347916020290026
# c_t =  9.722691090319275e-18
# weights['t'][15] =  3.1450879488086995e-17
# sum(weights) =  6.036713635145932e-05
# proba[15] =  0.0
# theta['t'][15] = [ 1.45200e+00 -2.00000e-01  2.59168e+02 -2.83042e+02] accepted !
# ###########    i =  16
# theta["t"][16]=  [ 1.41621801e+00 -2.73993742e-02  2.59754737e+02 -2.84796851e+02]
# rapport W_i/c_t =  6.094700922913934
# c_t =  9.722691090319275e-18
# weights['t'][16] =  5.925689436137597e-17
# sum(weights) =  6.036713635150885e-05
# proba[16] =  0.0
# theta['t'][16] = [ 1.41600e+00 -2.70000e-02  2.59755e+02 -2.84797e+02] accepted !
# ###########    i =  17
# theta["t"][17]=  [ 1.63002325e+00 -1.24899083e-01  2.58575896e+02 -2.84039236e+02]
# rapport W_i/c_t =  2.007280701607489
# c_t =  9.722691090319275e-18
# weights['t'][17] =  1.9516170193288958e-17
# sum(weights) =  6.0367136351518645e-05
# proba[17] =  0.0
# theta['t'][17] = [ 1.63000e+00 -1.25000e-01  2.58576e+02 -2.84039e+02] accepted !
# ###########    i =  18
# theta["t"][18]=  [ 1.47555369e+00  1.07481852e-01  2.56784427e+02 -2.85201428e+02]
# rapport W_i/c_t =  26.342801667297948
# c_t =  9.722691090319275e-18
# weights['t'][18] =  2.561229230646855e-16
# sum(weights) =  6.036713635176504e-05
# proba[18] =  0.0
# theta['t'][18] = [ 1.47600e+00  1.07000e-01  2.56784e+02 -2.85201e+02] accepted !
# ###########    i =  19
# theta["t"][19]=  [ 1.97775055e+00 -2.24270039e-01  2.57297719e+02 -2.82873598e+02]
# rapport W_i/c_t =  12.450457369031232
# c_t =  9.722691090319275e-18
# weights['t'][19] =  1.2105195093227992e-16
# sum(weights) =  6.036713635187637e-05
# proba[19] =  0.0
# theta['t'][19] = [ 1.97800e+00 -2.24000e-01  2.57298e+02 -2.82874e+02] accepted !
# ###########    i =  20
# theta["t"][20]=  [   1.37670134   -0.88497948  258.47022781 -284.97553131]
# rapport W_i/c_t =  3.900094096312979
# c_t =  9.722691090319275e-18
# weights['t'][20] =  3.7919410121629006e-17
# sum(weights) =  6.0367136351904566e-05
# proba[20] =  0.0
# theta['t'][20] = [   1.377   -0.885  258.47  -284.976] accepted !
# ###########    i =  21
# the prior is O
# ###########    i =  21
# theta["t"][21]=  [   1.55577249    0.6121858   257.64080608 -283.89566569]
# rapport W_i/c_t =  20.184376495815947
# c_t =  9.722691090319275e-18
# weights['t'][21] =  1.9624645751951948e-16
# sum(weights) =  6.036713635209109e-05
# proba[21] =  0.0
# theta['t'][21] = [   1.556    0.612  257.641 -283.896] accepted !
# ###########    i =  22
# the prior is O
# ###########    i =  22
# theta["t"][22]=  [ 1.48849733e+00  2.37347380e-03  2.57439478e+02 -2.83853434e+02]
# rapport W_i/c_t =  4.09684708324899
# c_t =  9.722691090319275e-18
# weights['t'][22] =  3.9832378634705466e-17
# sum(weights) =  6.0367136352121203e-05
# proba[22] =  0.0
# theta['t'][22] = [ 1.48800e+00  2.00000e-03  2.57439e+02 -2.83853e+02] accepted !
# ###########    i =  23
# the prior is O
# ###########    i =  23
# the prior is O
# ###########    i =  23
# theta["t"][23]=  [   1.21196874    0.78049149  257.83801281 -286.18060526]
# rapport W_i/c_t =  424.4655596953563
# c_t =  9.722691090319275e-18
# weights['t'][23] =  4.126947515397425e-15
# sum(weights) =  6.036713635623843e-05
# proba[23] =  0.0
# theta['t'][23] = [   1.212    0.78   257.838 -286.181] accepted !
# ###########    i =  24
# theta["t"][24]=  [ 1.67516177e+00  9.62126299e-02  2.58998304e+02 -2.83600563e+02]
# rapport W_i/c_t =  3.578508581056783
# c_t =  9.722691090319275e-18
# weights['t'][24] =  3.479273349767185e-17
# sum(weights) =  6.03671363562635e-05
# proba[24] =  0.0
# theta['t'][24] = [ 1.67500e+00  9.60000e-02  2.58998e+02 -2.83601e+02] accepted !
# ###########    i =  25
# theta["t"][25]=  [   1.55674398   -0.69127736  258.86287999 -283.35413397]
# rapport W_i/c_t =  2.3863607322561675
# c_t =  9.722691090319275e-18
# weights['t'][25] =  2.320184822979482e-17
# sum(weights) =  6.036713635627698e-05
# proba[25] =  0.0
# theta['t'][25] = [   1.557   -0.691  258.863 -283.354] accepted !
# ###########    i =  26
# the prior is O
# ###########    i =  26
# theta["t"][26]=  [ 1.69061294e+00  7.32450378e-02  2.56790052e+02 -2.84848293e+02]
# rapport W_i/c_t =  19.41645772555957
# c_t =  9.722691090319275e-18
# weights['t'][26] =  1.887802205338589e-16
# sum(weights) =  6.036713635645604e-05
# proba[26] =  0.0
# theta['t'][26] = [ 1.69100e+00  7.30000e-02  2.56790e+02 -2.84848e+02] accepted !
# ###########    i =  27
# theta["t"][27]=  [   1.72575407   -0.61629093  257.69118978 -285.11029769]
# rapport W_i/c_t =  5.417009821899632
# c_t =  9.722691090319275e-18
# weights['t'][27] =  5.266791313155556e-17
# sum(weights) =  6.036713635649898e-05
# proba[27] =  0.0
# theta['t'][27] = [   1.726   -0.616  257.691 -285.11 ] accepted !
# ###########    i =  28
# theta["t"][28]=  [   1.44720895   -0.91609987  259.74459818 -283.85282509]
# rapport W_i/c_t =  5.273674725548915
# c_t =  9.722691090319275e-18
# weights['t'][28] =  5.127431026733638e-17
# sum(weights) =  6.0367136356540533e-05
# proba[28] =  0.0
# theta['t'][28] = [   1.447   -0.916  259.745 -283.853] accepted !
# ###########    i =  29
# theta["t"][29]=  [   1.70730956   -0.71328806  258.05564653 -283.61315912]
# rapport W_i/c_t =  2.6047569435518154
# c_t =  9.722691090319275e-18
# weights['t'][29] =  2.53252471275185e-17
# sum(weights) =  6.036713635655613e-05
# proba[29] =  0.0
# theta['t'][29] = [   1.707   -0.713  258.056 -283.613] accepted !
# ###########    i =  30
# theta["t"][30]=  [ 1.89720770e+00  1.28388772e-01  2.58334661e+02 -2.82766956e+02]
# rapport W_i/c_t =  9.522241959478292
# c_t =  9.722691090319275e-18
# weights['t'][30] =  9.258181705928393e-17
# sum(weights) =  6.036713635663899e-05
# proba[30] =  0.0
# theta['t'][30] = [ 1.89700e+00  1.28000e-01  2.58335e+02 -2.82767e+02] accepted !
# ###########    i =  31
# the prior is O
# ###########    i =  31
# theta["t"][31]=  [ 1.68758254e+00  1.09512393e-01  2.57666258e+02 -2.83766985e+02]
# rapport W_i/c_t =  4.666986603013294
# c_t =  9.722691090319275e-18
# weights['t'][31] =  4.537566906375677e-17
# sum(weights) =  6.036713635667464e-05
# proba[31] =  0.0
# theta['t'][31] = [ 1.68800e+00  1.10000e-01  2.57666e+02 -2.83767e+02] accepted !
# ###########    i =  32
# the prior is O
# ###########    i =  32
# theta["t"][32]=  [ 1.67128713e+00 -1.44313177e-01  2.58666956e+02 -2.85245572e+02]
# rapport W_i/c_t =  4.539009823237141
# c_t =  9.722691090319275e-18
# weights['t'][32] =  4.413139036725942e-17
# sum(weights) =  6.036713635670905e-05
# proba[32] =  0.0
# theta['t'][32] = [ 1.67100e+00 -1.44000e-01  2.58667e+02 -2.85246e+02] accepted !
# ###########    i =  33
# theta["t"][33]=  [   1.22316518   -0.79745176  259.15806693 -283.62348317]
# rapport W_i/c_t =  2.861477581655362
# c_t =  9.722691090319275e-18
# weights['t'][33] =  2.782126258830893e-17
# sum(weights) =  6.036713635672715e-05
# proba[33] =  0.0
# theta['t'][33] = [   1.223   -0.797  259.158 -283.623] accepted !
# ###########    i =  34
# the prior is O
# ###########    i =  34
# the prior is O
# ###########    i =  34
# the prior is O
# ###########    i =  34
# theta["t"][34]=  [   1.52565539   -0.513549    258.55679927 -284.18983077]
# rapport W_i/c_t =  1.63790823190608
# c_t =  9.722691090319275e-18
# weights['t'][34] =  1.5924875773113842e-17
# sum(weights) =  6.036713635673335e-05
# proba[34] =  0.0
# theta['t'][34] = [   1.526   -0.514  258.557 -284.19 ] accepted !
# ###########    i =  35
# the prior is O
# ###########    i =  35
# theta["t"][35]=  [   1.73389054   -0.73639577  258.49233038 -285.73616264]
# rapport W_i/c_t =  10.641308381672609
# c_t =  9.722691090319275e-18
# weights['t'][35] =  1.0346215419182809e-16
# sum(weights) =  6.0367136356827095e-05
# proba[35] =  0.0
# theta['t'][35] = [   1.734   -0.736  258.492 -285.736] accepted !
# ###########    i =  36
# the prior is O
# ###########    i =  36
# the prior is O
# ###########    i =  36
# theta["t"][36]=  [   1.40709268   -0.78814482  256.66502929 -284.31516149]
# rapport W_i/c_t =  12.348890996505379
# c_t =  9.722691090319275e-18
# weights['t'][36] =  1.2006445246704675e-16
# sum(weights) =  6.036713635693744e-05
# proba[36] =  0.0
# theta['t'][36] = [   1.407   -0.788  256.665 -284.315] accepted !
# ###########    i =  37
# theta["t"][37]=  [ 1.81447218e+00  9.03791539e-02  2.59533094e+02 -2.84848086e+02]
# rapport W_i/c_t =  8.425559490136404
# c_t =  9.722691090319275e-18
# weights['t'][37] =  8.191911218570423e-17
# sum(weights) =  6.0367136357009634e-05
# proba[37] =  0.0
# theta['t'][37] = [ 1.81400e+00  9.00000e-02  2.59533e+02 -2.84848e+02] accepted !
# ###########    i =  38
# theta["t"][38]=  [ 1.38611177e+00 -8.70083124e-02  2.58501694e+02 -2.84570112e+02]
# rapport W_i/c_t =  2.2847630029205814
# c_t =  9.722691090319275e-18
# weights['t'][38] =  2.2214044891987048e-17
# sum(weights) =  6.036713635702213e-05
# proba[38] =  0.0
# theta['t'][38] = [ 1.38600e+00 -8.70000e-02  2.58502e+02 -2.84570e+02] accepted !
# ###########    i =  39
# the prior is O
# ###########    i =  39
# the prior is O
# ###########    i =  39
# theta["t"][39]=  [ 1.37730385e+00 -2.53786259e-01  2.60529033e+02 -2.83005573e+02]
# rapport W_i/c_t =  19.12547845375591
# c_t =  9.722691090319275e-18
# weights['t'][39] =  1.8595111896042585e-16
# sum(weights) =  6.036713635719835e-05
# proba[39] =  0.0
# theta['t'][39] = [ 1.37700e+00 -2.54000e-01  2.60529e+02 -2.83006e+02] accepted !
# ###########    i =  40
# theta["t"][40]=  [   1.8882912    -0.57292667  258.51516104 -283.30990606]
# rapport W_i/c_t =  3.154585968870111
# c_t =  9.722691090319275e-18
# weights['t'][40] =  3.0671064893179624e-17
# sum(weights) =  6.03671363572193e-05
# proba[40] =  0.0
# theta['t'][40] = [   1.888   -0.573  258.515 -283.31 ] accepted !
# ###########    i =  41
# the prior is O
# ###########    i =  41
# the prior is O
# ###########    i =  41
# the prior is O
# ###########    i =  41
# theta["t"][41]=  [   1.48744151   -0.83014401  257.81273733 -283.39664478]
# rapport W_i/c_t =  3.3725891816008073
# c_t =  9.722691090319275e-18
# weights['t'][41] =  3.2790642787257345e-17
# sum(weights) =  6.0367136357242365e-05
# proba[41] =  0.0
# theta['t'][41] = [   1.487   -0.83   257.813 -283.397] accepted !
# ###########    i =  42
# theta["t"][42]=  [   1.90730659   -0.91421356  257.74440206 -283.37871415]
# rapport W_i/c_t =  6.678588580913431
# c_t =  9.722691090319275e-18
# weights['t'][42] =  6.493385369155506e-17
# sum(weights) =  6.036713635729758e-05
# proba[42] =  0.0
# theta['t'][42] = [   1.907   -0.914  257.744 -283.379] accepted !
# ###########    i =  43
# the prior is O
# ###########    i =  43
# the prior is O
# ###########    i =  43
# theta["t"][43]=  [   1.71115328   -0.31712489  258.88019397 -283.78402225]
# rapport W_i/c_t =  2.0189095387474705
# c_t =  9.722691090319275e-18
# weights['t'][43] =  1.962923378454063e-17
# sum(weights) =  6.0367136357307485e-05
# proba[43] =  0.0
# theta['t'][43] = [   1.711   -0.317  258.88  -283.784] accepted !
# ###########    i =  44
# theta["t"][44]=  [ 1.51942858e+00 -2.52961866e-01  2.59493077e+02 -2.82892483e+02]
# rapport W_i/c_t =  4.7611082039763515
# c_t =  9.722691090319275e-18
# weights['t'][44] =  4.6290784314846875e-17
# sum(weights) =  6.0367136357344056e-05
# proba[44] =  0.0
# theta['t'][44] = [ 1.51900e+00 -2.53000e-01  2.59493e+02 -2.82892e+02] accepted !
# ###########    i =  45
# the prior is O
# ###########    i =  45
# theta["t"][45]=  [ 1.44660753e+00 -2.74420841e-01  2.58025164e+02 -2.83954899e+02]
# rapport W_i/c_t =  1.8361962261924263
# c_t =  9.722691090319275e-18
# weights['t'][45] =  1.785276868847898e-17
# sum(weights) =  6.036713635735219e-05
# proba[45] =  0.0
# theta['t'][45] = [ 1.44700e+00 -2.74000e-01  2.58025e+02 -2.83955e+02] accepted !
# ###########    i =  46
# theta["t"][46]=  [ 1.99922510e+00 -1.06125680e-01  2.58990103e+02 -2.84174628e+02]
# rapport W_i/c_t =  4.146009797918085
# c_t =  9.722691090319275e-18
# weights['t'][46] =  4.0310372522594575e-17
# sum(weights) =  6.0367136357382776e-05
# proba[46] =  0.0
# theta['t'][46] = [ 1.99900e+00 -1.06000e-01  2.58990e+02 -2.84175e+02] accepted !
# ###########    i =  47
# the prior is O
# ###########    i =  47
# theta["t"][47]=  [   1.34400247   -0.69672478  258.43666685 -283.23395684]
# rapport W_i/c_t =  2.4216410439992955
# c_t =  9.722691090319275e-18
# weights['t'][47] =  2.3544867802443418e-17
# sum(weights) =  6.036713635739659e-05
# proba[47] =  0.0
# theta['t'][47] = [   1.344   -0.697  258.437 -283.234] accepted !
# ###########    i =  48
# the prior is O
# ###########    i =  48
# theta["t"][48]=  [   1.47874324   -0.49299132  258.73416231 -283.06864972]
# rapport W_i/c_t =  2.4337250238076207
# c_t =  9.722691090319275e-18
# weights['t'][48] =  2.366235660526142e-17
# sum(weights) =  6.036713635741053e-05
# proba[48] =  0.0
# theta['t'][48] = [   1.479   -0.493  258.734 -283.069] accepted !
# ###########    i =  49
# the prior is O
# ###########    i =  49
# the prior is O
# ###########    i =  49
# theta["t"][49]=  [ 1.40226605e+00 -2.20944873e-01  2.59314052e+02 -2.83272008e+02]
# rapport W_i/c_t =  2.9046119385914526
# c_t =  9.722691090319275e-18
# weights['t'][49] =  2.824064461617811e-17
# sum(weights) =  6.036713635742905e-05
# proba[49] =  0.0
# theta['t'][49] = [ 1.40200e+00 -2.21000e-01  2.59314e+02 -2.83272e+02] accepted !
# ###########    i =  50
# the prior is O
# ###########    i =  50
# theta["t"][50]=  [ 1.30085494e+00 -7.58003219e-02  2.56548552e+02 -2.85297937e+02]
# rapport W_i/c_t =  34.360263719448504
# c_t =  9.722691090319275e-18
# weights['t'][50] =  3.340742299261026e-16
# sum(weights) =  6.0367136357753397e-05
# proba[50] =  0.0
# theta['t'][50] = [ 1.30100e+00 -7.60000e-02  2.56549e+02 -2.85298e+02] accepted !
# ###########    i =  51
# theta["t"][51]=  [   1.66035963   -0.49977082  259.05723391 -283.43078651]
# rapport W_i/c_t =  2.339700613385563
# c_t =  9.722691090319275e-18
# weights['t'][51] =  2.2748186307778354e-17
# sum(weights) =  6.036713635776643e-05
# proba[51] =  0.0
# theta['t'][51] = [   1.66    -0.5    259.057 -283.431] accepted !
# ###########    i =  52
# theta["t"][52]=  [   1.7284141    -0.81877549  258.34775901 -284.62229991]
# rapport W_i/c_t =  3.2016201887151357
# c_t =  9.722691090319275e-18
# weights['t'][52] =  3.1128364083406964e-17
# sum(weights) =  6.0367136357787834e-05
# proba[52] =  0.0
# theta['t'][52] = [   1.728   -0.819  258.348 -284.622] accepted !
# ###########    i =  53
# the prior is O
# ###########    i =  53
# the prior is O
# ###########    i =  53
# theta["t"][53]=  [   1.94429899   -0.57056463  259.46875519 -285.18379812]
# rapport W_i/c_t =  8.850788448612652
# c_t =  9.722691090319275e-18
# weights['t'][53] =  8.605348199162699e-17
# sum(weights) =  6.036713635786417e-05
# proba[53] =  0.0
# theta['t'][53] = [   1.944   -0.571  259.469 -285.184] accepted !
# ###########    i =  54
# the prior is O
# ###########    i =  54
# theta["t"][54]=  [ 1.13684247e+00 -1.81541054e-01  2.58110236e+02 -2.83453484e+02]
# rapport W_i/c_t =  2.5523710203630636
# c_t =  9.722691090319275e-18
# weights['t'][54] =  2.4815914978873076e-17
# sum(weights) =  6.036713635787926e-05
# proba[54] =  0.0
# theta['t'][54] = [ 1.13700e+00 -1.82000e-01  2.58110e+02 -2.83453e+02] accepted !
# ###########    i =  55
# the prior is O
# ###########    i =  55
# theta["t"][55]=  [ 1.59677174e+00 -9.40835866e-02  2.58165336e+02 -2.85139495e+02]
# rapport W_i/c_t =  4.230237673073531
# c_t =  9.722691090319275e-18
# weights['t'][55] =  4.1129294133924964e-17
# sum(weights) =  6.036713635791067e-05
# proba[55] =  0.0
# theta['t'][55] = [ 1.59700e+00 -9.40000e-02  2.58165e+02 -2.85139e+02] accepted !
# ###########    i =  56
# the prior is O
# ###########    i =  56
# theta["t"][56]=  [ 1.15486913e+00 -2.60122016e-01  2.57835900e+02 -2.84299518e+02]
# rapport W_i/c_t =  2.5036061462289725
# c_t =  9.722691090319275e-18
# weights['t'][56] =  2.4341789171609006e-17
# sum(weights) =  6.036713635792528e-05
# proba[56] =  0.0
# theta['t'][56] = [ 1.15500e+00 -2.60000e-01  2.57836e+02 -2.84300e+02] accepted !
# ###########    i =  57
# the prior is O
# ###########    i =  57
# theta["t"][57]=  [ 1.87579450e+00 -1.00722574e-01  2.58163417e+02 -2.82527365e+02]
# rapport W_i/c_t =  8.906880354762263
# c_t =  9.722691090319275e-18
# weights['t'][57] =  8.659884626778683e-17
# sum(weights) =  6.036713635800216e-05
# proba[57] =  0.0
# theta['t'][57] = [ 1.87600e+00 -1.01000e-01  2.58163e+02 -2.82527e+02] accepted !
# ###########    i =  58
# the prior is O
# ###########    i =  58
# theta["t"][58]=  [ 1.23426062e+00  1.89025257e-01  2.61301010e+02 -2.84187180e+02]
# rapport W_i/c_t =  160.04590631327025
# c_t =  9.722691090319275e-18
# weights['t'][58] =  1.556076907354106e-15
# sum(weights) =  6.036713635954851e-05
# proba[58] =  0.0
# theta['t'][58] = [ 1.23400e+00  1.89000e-01  2.61301e+02 -2.84187e+02] accepted !
# ###########    i =  59
# theta["t"][59]=  [   1.81319455   -0.95521079  257.69955574 -283.89438134]
# rapport W_i/c_t =  5.331901934367475
# c_t =  9.722691090319275e-18
# weights['t'][59] =  5.184043543173076e-17
# sum(weights) =  6.036713635959063e-05
# proba[59] =  0.0
# theta['t'][59] = [   1.813   -0.955  257.7   -283.894] accepted !
# ###########    i =  60
# the prior is O
# ###########    i =  60
# the prior is O
# ###########    i =  60
# theta["t"][60]=  [   1.52058582   -0.62456888  259.90011715 -284.47499633]
# rapport W_i/c_t =  4.8704242830752955
# c_t =  9.722691090319275e-18
# weights['t'][60] =  4.735363078313082e-17
# sum(weights) =  6.036713635962826e-05
# proba[60] =  0.0
# theta['t'][60] = [   1.521   -0.625  259.9   -284.475] accepted !
# ###########    i =  61
# the prior is O
# ###########    i =  61
# the prior is O
# ###########    i =  61
# theta["t"][61]=  [   1.19206087   -0.35560395  257.03114515 -283.6431655 ]
# rapport W_i/c_t =  5.683163945980772
# c_t =  9.722691090319275e-18
# weights['t'][61] =  5.5255647462410985e-17
# sum(weights) =  6.0367136359673796e-05
# proba[61] =  0.0
# theta['t'][61] = [   1.192   -0.356  257.031 -283.643] accepted !
# ###########    i =  62
# the prior is O
# ###########    i =  62
# the prior is O
# ###########    i =  62
# theta["t"][62]=  [   1.4155773    -0.37602916  257.34097744 -284.47217081]
# rapport W_i/c_t =  3.564876624257327
# c_t =  9.722691090319275e-18
# weights['t'][62] =  3.466019419275417e-17
# sum(weights) =  6.036713635969873e-05
# proba[62] =  0.0
# theta['t'][62] = [   1.416   -0.376  257.341 -284.472] accepted !
# ###########    i =  63
# theta["t"][63]=  [ 1.28644238e+00  4.18113126e-02  2.57755950e+02 -2.83161882e+02]
# rapport W_i/c_t =  4.654190223645049
# c_t =  9.722691090319275e-18
# weights['t'][63] =  4.525125382008479e-17
# sum(weights) =  6.036713635973426e-05
# proba[63] =  0.0
# theta['t'][63] = [ 1.28600e+00  4.20000e-02  2.57756e+02 -2.83162e+02] accepted !
# ###########    i =  64
# the prior is O
# ###########    i =  64
# the prior is O
# ###########    i =  64
# theta["t"][64]=  [   1.83423417   -0.43619289  258.87719479 -281.80218005]
# rapport W_i/c_t =  25.005527489611712
# c_t =  9.722691090319275e-18
# weights['t'][64] =  2.431210193319815e-16
# sum(weights) =  6.0367136359967656e-05
# proba[64] =  0.0
# theta['t'][64] = [   1.834   -0.436  258.877 -281.802] accepted !
# ###########    i =  65
# the prior is O
# ###########    i =  65
# the prior is O
# ###########    i =  65
# the prior is O
# ###########    i =  65
# theta["t"][65]=  [   1.48139796   -0.56779116  259.69680996 -283.16565017]
# rapport W_i/c_t =  4.439458452364472
# c_t =  9.722691090319275e-18
# weights['t'][65] =  4.316348314064665e-17
# sum(weights) =  6.03671363600011e-05
# proba[65] =  0.0
# theta['t'][65] = [   1.481   -0.568  259.697 -283.166] accepted !
# ###########    i =  66
# the prior is O
# ###########    i =  66
# the prior is O
# ###########    i =  66
# the prior is O
# ###########    i =  66
# theta["t"][66]=  [ 1.69128618e+00 -2.50841046e-01  2.58328324e+02 -2.85162935e+02]
# rapport W_i/c_t =  3.8667636487583357
# c_t =  9.722691090319275e-18
# weights['t'][66] =  3.759534847615312e-17
# sum(weights) =  6.036713636002897e-05
# proba[66] =  0.0
# theta['t'][66] = [ 1.69100e+00 -2.51000e-01  2.58328e+02 -2.85163e+02] accepted !
# ###########    i =  67
# the prior is O
# ###########    i =  67
# the prior is O
# ###########    i =  67
# the prior is O
# ###########    i =  67
# the prior is O
# ###########    i =  67
# theta["t"][67]=  [ 1.14068347e+00  6.78692010e-02  2.58194853e+02 -2.84090086e+02]
# rapport W_i/c_t =  3.081978976696328
# c_t =  9.722691090319275e-18
# weights['t'][67] =  2.9965129537276705e-17
# sum(weights) =  6.036713636004921e-05
# proba[67] =  0.0
# theta['t'][67] = [ 1.14100e+00  6.80000e-02  2.58195e+02 -2.84090e+02] accepted !
# ###########    i =  68
# theta["t"][68]=  [   1.35465889   -0.43282423  257.67186677 -285.43889973]
# rapport W_i/c_t =  6.5003808124144795
# c_t =  9.722691090319275e-18
# weights['t'][68] =  6.320119460854463e-17
# sum(weights) =  6.0367136360102686e-05
# proba[68] =  0.0
# theta['t'][68] = [   1.355   -0.433  257.672 -285.439] accepted !
# ###########    i =  69
# theta["t"][69]=  [ 1.70554743e+00 -1.35386013e-01  2.59721770e+02 -2.84292856e+02]
# rapport W_i/c_t =  4.503281755402347
# c_t =  9.722691090319275e-18
# weights['t'][69] =  4.378401740044774e-17
# sum(weights) =  6.036713636013675e-05
# proba[69] =  0.0
# theta['t'][69] = [ 1.70600e+00 -1.35000e-01  2.59722e+02 -2.84293e+02] accepted !
# ###########    i =  70
# theta["t"][70]=  [ 1.80736820e+00 -2.92912352e-02  2.59023734e+02 -2.81907184e+02]
# rapport W_i/c_t =  27.556586130623664
# c_t =  9.722691090319275e-18
# weights['t'][70] =  2.679241744518304e-16
# sum(weights) =  6.036713636039495e-05
# proba[70] =  0.0
# theta['t'][70] = [ 1.80700e+00 -2.90000e-02  2.59024e+02 -2.81907e+02] accepted !
# ###########    i =  71
# theta["t"][71]=  [   1.27022496   -0.71606797  260.80484196 -282.9490153 ]
# rapport W_i/c_t =  42.81137684233373
# c_t =  9.722691090319275e-18
# weights['t'][71] =  4.1624179218925907e-16
# sum(weights) =  6.036713636080147e-05
# proba[71] =  0.0
# theta['t'][71] = [   1.27    -0.716  260.805 -282.949] accepted !
# ###########    i =  72
# the prior is O
# ###########    i =  72
# theta["t"][72]=  [   1.69571854   -0.69589251  259.57495918 -284.35218766]
# rapport W_i/c_t =  3.828086403205084
# c_t =  9.722691090319275e-18
# weights['t'][72] =  3.721930156541443e-17
# sum(weights) =  6.0367136360828966e-05
# proba[72] =  0.0
# theta['t'][72] = [   1.696   -0.696  259.575 -284.352] accepted !
# ###########    i =  73
# the prior is O
# ###########    i =  73
# theta["t"][73]=  [   1.77823268   -0.63430563  258.1038429  -282.29263009]
# rapport W_i/c_t =  10.081343408793957
# c_t =  9.722691090319275e-18
# weights['t'][73] =  9.801778773912996e-17
# sum(weights) =  6.036713636091726e-05
# proba[73] =  0.0
# theta['t'][73] = [   1.778   -0.634  258.104 -282.293] accepted !
# ###########    i =  74
# the prior is O
# ###########    i =  74
# theta["t"][74]=  [ 1.33296159e+00 -2.46629088e-01  2.58965009e+02 -2.85210511e+02]
# rapport W_i/c_t =  3.845974715273691
# c_t =  9.722691090319275e-18
# weights['t'][74] =  3.7393224097784726e-17
# sum(weights) =  6.0367136360944935e-05
# proba[74] =  0.0
# theta['t'][74] = [ 1.33300e+00 -2.47000e-01  2.58965e+02 -2.85211e+02] accepted !
# ###########    i =  75
# the prior is O
# ###########    i =  75
# the prior is O
# ###########    i =  75
# theta["t"][75]=  [   1.97705434   -0.74497615  259.03270479 -283.42622009]
# rapport W_i/c_t =  4.693418654072315
# c_t =  9.722691090319275e-18
# weights['t'][75] =  4.5632659731087175e-17
# sum(weights) =  6.036713636098084e-05
# proba[75] =  0.0
# theta['t'][75] = [   1.977   -0.745  259.033 -283.426] accepted !
# ###########    i =  76
# theta["t"][76]=  [   1.28222965   -0.94191937  257.8873641  -284.71877573]
# rapport W_i/c_t =  4.462831946637229
# c_t =  9.722691090319275e-18
# weights['t'][76] =  4.339073640516201e-17
# sum(weights) =  6.0367136361014514e-05
# proba[76] =  0.0
# theta['t'][76] = [   1.282   -0.942  257.887 -284.719] accepted !
# ###########    i =  77
# theta["t"][77]=  [   1.37106196   -0.51393757  259.81338494 -283.62780471]
# rapport W_i/c_t =  3.7832076259866496
# c_t =  9.722691090319275e-18
# weights['t'][77] =  3.6782959078008334e-17
# sum(weights) =  6.036713636104157e-05
# proba[77] =  0.0
# theta['t'][77] = [   1.371   -0.514  259.813 -283.628] accepted !
# ###########    i =  78
# theta["t"][78]=  [   1.25358807   -0.42554105  259.70450287 -282.59703751]
# rapport W_i/c_t =  8.414625281225502
# c_t =  9.722691090319275e-18
# weights['t'][78] =  8.181280225014651e-17
# sum(weights) =  6.0367136361113664e-05
# proba[78] =  0.0
# theta['t'][78] = [   1.254   -0.426  259.705 -282.597] accepted !
# ###########    i =  79
# the prior is O
# ###########    i =  79
# theta["t"][79]=  [   1.4483252    -0.98245135  260.09499848 -283.77926394]
# rapport W_i/c_t =  9.973234935686792
# c_t =  9.722691090319275e-18
# weights['t'][79] =  9.69666824508629e-17
# sum(weights) =  6.036713636120091e-05
# proba[79] =  0.0
# theta['t'][79] = [   1.448   -0.982  260.095 -283.779] accepted !
# ###########    i =  80
# theta["t"][80]=  [ 1.64975072e+00 -2.60197910e-01  2.56466947e+02 -2.86009339e+02]
# rapport W_i/c_t =  119.46224632993847
# c_t =  9.722691090319275e-18
# weights['t'][80] =  1.1614945180216191e-15
# sum(weights) =  6.036713636235268e-05
# proba[80] =  0.0
# theta['t'][80] = [ 1.65000e+00 -2.60000e-01  2.56467e+02 -2.86009e+02] accepted !
# ###########    i =  81
# the prior is O
# ###########    i =  81
# the prior is O
# ###########    i =  81
# theta["t"][81]=  [   1.66505098   -0.37213686  258.77077952 -282.11052652]
# rapport W_i/c_t =  10.410630723673671
# c_t =  9.722691090319275e-18
# weights['t'][81] =  1.012193465816661e-16
# sum(weights) =  6.036713636244418e-05
# proba[81] =  0.0
# theta['t'][81] = [   1.665   -0.372  258.771 -282.111] accepted !
# ###########    i =  82
# the prior is O
# ###########    i =  82
# theta["t"][82]=  [   1.31943652   -0.91430988  260.03982931 -283.98118866]
# rapport W_i/c_t =  7.9086131568441855
# c_t =  9.722691090319275e-18
# weights['t'][82] =  7.689300267683076e-17
# sum(weights) =  6.036713636251135e-05
# proba[82] =  0.0
# theta['t'][82] = [   1.319   -0.914  260.04  -283.981] accepted !
# ###########    i =  83
# theta["t"][83]=  [ 1.39862142e+00 -2.59268876e-01  2.58971138e+02 -2.83797829e+02]
# rapport W_i/c_t =  1.812968310355562
# c_t =  9.722691090319275e-18
# weights['t'][83] =  1.7626930838125214e-17
# sum(weights) =  6.036713636251925e-05
# proba[83] =  0.0
# theta['t'][83] = [ 1.39900e+00 -2.59000e-01  2.58971e+02 -2.83798e+02] accepted !
# ###########    i =  84
# the prior is O
# ###########    i =  84
# theta["t"][84]=  [   1.46552813   -0.61149894  258.07517311 -284.27676278]
# rapport W_i/c_t =  1.9343232696090977
# c_t =  9.722691090319275e-18
# weights['t'][84] =  1.8806827619225623e-17
# sum(weights) =  6.036713636252833e-05
# proba[84] =  0.0
# theta['t'][84] = [   1.466   -0.611  258.075 -284.277] accepted !
# ###########    i =  85
# the prior is O
# ###########    i =  85
# theta["t"][85]=  [   1.93753037   -0.63937872  259.72961744 -283.21268277]
# rapport W_i/c_t =  7.9657526321786625
# c_t =  9.722691090319275e-18
# weights['t'][85] =  7.744855214457079e-17
# sum(weights) =  6.036713636259606e-05
# proba[85] =  0.0
# theta['t'][85] = [   1.938   -0.639  259.73  -283.213] accepted !
# ###########    i =  86
# the prior is O
# ###########    i =  86
# the prior is O
# ###########    i =  86
# the prior is O
# ###########    i =  86
# theta["t"][86]=  [   1.53872587   -0.5333037   258.23848884 -285.12499053]
# rapport W_i/c_t =  3.256446765913362
# c_t =  9.722691090319275e-18
# weights['t'][86] =  3.166142595704486e-17
# sum(weights) =  6.0367136362617995e-05
# proba[86] =  0.0
# theta['t'][86] = [   1.539   -0.533  258.238 -285.125] accepted !
# ###########    i =  87
# theta["t"][87]=  [   1.43652222   -0.83687343  256.72238696 -284.78791353]
# rapport W_i/c_t =  15.6778324371004
# c_t =  9.722691090319275e-18
# weights['t'][87] =  1.5243072175171459e-16
# sum(weights) =  6.03671363627607e-05
# proba[87] =  0.0
# theta['t'][87] = [   1.437   -0.837  256.722 -284.788] accepted !
# ###########    i =  88
# the prior is O
# ###########    i =  88
# theta["t"][88]=  [ 1.19436247e+00 -1.90443604e-02  2.59589136e+02 -2.82112583e+02]
# rapport W_i/c_t =  23.542521809855764
# c_t =  9.722691090319275e-18
# weights['t'][88] =  2.2889666704433184e-16
# sum(weights) =  6.0367136362979874e-05
# proba[88] =  0.0
# theta['t'][88] = [ 1.19400e+00 -1.90000e-02  2.59589e+02 -2.82113e+02] accepted !
# ###########    i =  89
# the prior is O
# ###########    i =  89
# the prior is O
# ###########    i =  89
# theta["t"][89]=  [   1.91428194   -0.39782927  258.60196139 -284.37559853]
# rapport W_i/c_t =  2.724301676266234
# c_t =  9.722691090319275e-18
# weights['t'][89] =  2.648754363517558e-17
# sum(weights) =  6.036713636299664e-05
# proba[89] =  0.0
# theta['t'][89] = [   1.914   -0.398  258.602 -284.376] accepted !
# ###########    i =  90
# the prior is O
# ###########    i =  90
# theta["t"][90]=  [ 1.66256463e+00  2.69912490e-01  2.57884654e+02 -2.83725096e+02]
# rapport W_i/c_t =  5.748814942472518
# c_t =  9.722691090319275e-18
# weights['t'][90] =  5.589395182107186e-17
# sum(weights) =  6.036713636304281e-05
# proba[90] =  0.0
# theta['t'][90] = [ 1.66300e+00  2.70000e-01  2.57885e+02 -2.83725e+02] accepted !
# ###########    i =  91
# theta["t"][91]=  [ 1.74823041e+00 -3.41499124e-02  2.55431990e+02 -2.83718711e+02]
# rapport W_i/c_t =  332.77663707154073
# c_t =  9.722691090319275e-18
# weights['t'][91] =  3.23548444432188e-15
# sum(weights) =  6.036713636626857e-05
# proba[91] =  0.0
# theta['t'][91] = [ 1.74800e+00 -3.40000e-02  2.55432e+02 -2.83719e+02] accepted !
# ###########    i =  92
# theta["t"][92]=  [   1.22387339   -0.70793167  257.48605021 -281.6857163 ]
# rapport W_i/c_t =  48.08917925403323
# c_t =  9.722691090319275e-18
# weights['t'][92] =  4.675562346739554e-16
# sum(weights) =  6.036713636672641e-05
# proba[92] =  0.0
# theta['t'][92] = [   1.224   -0.708  257.486 -281.686] accepted !
# ###########    i =  93
# theta["t"][93]=  [   1.14134402   -0.32414995  258.13837939 -284.19207445]
# rapport W_i/c_t =  2.023817020115187
# c_t =  9.722691090319275e-18
# weights['t'][93] =  1.9676947709910434e-17
# sum(weights) =  6.0367136366736364e-05
# proba[93] =  0.0
# theta['t'][93] = [   1.141   -0.324  258.138 -284.192] accepted !
# ###########    i =  94
# the prior is O
# ###########    i =  94
# the prior is O
# ###########    i =  94
# the prior is O
# ###########    i =  94
# the prior is O
# ###########    i =  94
# the prior is O
# ###########    i =  94
# the prior is O
# ###########    i =  94
# theta["t"][94]=  [ 1.23641809e+00 -6.77051879e-02  2.61133697e+02 -2.83160978e+02]
# rapport W_i/c_t =  85.8429633329594
# c_t =  9.722691090319275e-18
# weights['t'][94] =  8.346246147639685e-16
# sum(weights) =  6.0367136367561266e-05
# proba[94] =  0.0
# theta['t'][94] = [ 1.23600e+00 -6.80000e-02  2.61134e+02 -2.83161e+02] accepted !
# ###########    i =  95
# the prior is O
# ###########    i =  95
# theta["t"][95]=  [   1.34832567   -0.40980558  258.75113101 -282.71109807]
# rapport W_i/c_t =  3.584649835619158
# c_t =  9.722691090319275e-18
# weights['t'][95] =  3.485244301868884e-17
# sum(weights) =  6.036713636758639e-05
# proba[95] =  0.0
# theta['t'][95] = [   1.348   -0.41   258.751 -282.711] accepted !
# ###########    i =  96
# theta["t"][96]=  [   1.63495437   -0.45659913  257.29422886 -283.81362647]
# rapport W_i/c_t =  3.7335473415932983
# c_t =  9.722691090319275e-18
# weights['t'][96] =  3.630012747339437e-17
# sum(weights) =  6.036713636761297e-05
# proba[96] =  0.0
# theta['t'][96] = [   1.635   -0.457  257.294 -283.814] accepted !
# ###########    i =  97
# the prior is O
# ###########    i =  97
# theta["t"][97]=  [   1.21912843   -0.42738763  258.62884629 -283.65650461]
# rapport W_i/c_t =  1.7676439231550132
# c_t =  9.722691090319275e-18
# weights['t'][97] =  1.7186255822516255e-17
# sum(weights) =  6.036713636762043e-05
# proba[97] =  0.0
# theta['t'][97] = [   1.219   -0.427  258.629 -283.657] accepted !
# ###########    i =  98
# theta["t"][98]=  [   1.72481422   -0.56695552  258.70377264 -282.287312  ]
# rapport W_i/c_t =  8.321126075415862
# c_t =  9.722691090319275e-18
# weights['t'][98] =  8.090373835486918e-17
# sum(weights) =  6.0367136367691614e-05
# proba[98] =  0.0
# theta['t'][98] = [   1.725   -0.567  258.704 -282.287] accepted !
# ###########    i =  99
# theta["t"][99]=  [ 1.37904734e+00 -1.63925899e-01  2.56305518e+02 -2.84913938e+02]
# rapport W_i/c_t =  32.77854705111845
# c_t =  9.722691090319275e-18
# weights['t'][99] =  3.186956873675205e-16
# sum(weights) =  6.0367136368000584e-05
# proba[99] =  0.0
# theta['t'][99] = [ 1.37900e+00 -1.64000e-01  2.56306e+02 -2.84914e+02] accepted !
# ###########    i =  100
# the prior is O
# ###########    i =  100
# the prior is O
# ###########    i =  100
# the prior is O
# ###########    i =  100
# the prior is O
# ###########    i =  100
# theta["t"][100]=  [   1.61806057   -0.53845467  260.14564841 -283.15264732]
# rapport W_i/c_t =  8.827153475283353
# c_t =  9.722691090319275e-18
# weights['t'][100] =  8.582368644701828e-17
# sum(weights) =  6.036713636807669e-05
# proba[100] =  0.0
# theta['t'][100] = [   1.618   -0.538  260.146 -283.153] accepted !
# ###########    i =  101
# the prior is O
# ###########    i =  101
# the prior is O
# ###########    i =  101
# the prior is O
# ###########    i =  101
# the prior is O
# ###########    i =  101
# the prior is O
# ###########    i =  101
# the prior is O
# ###########    i =  101
# the prior is O
# ###########    i =  101
# the prior is O
# ###########    i =  101
# the prior is O
# ###########    i =  101
# the prior is O
# ###########    i =  101
# theta["t"][101]=  [   1.26165629   -0.80047936  258.14515649 -283.99679928]
# rapport W_i/c_t =  2.3371158041991427
# c_t =  9.722691090319275e-18
# weights['t'][101] =  2.2723055006531372e-17
# sum(weights) =  6.0367136368089685e-05
# proba[101] =  0.0
# theta['t'][101] = [   1.262   -0.8    258.145 -283.997] accepted !
# ###########    i =  102
# theta["t"][102]=  [   1.11721696   -0.3627508   257.71929531 -284.20007839]
# rapport W_i/c_t =  2.6603192472820707
# c_t =  9.722691090319275e-18
# weights['t'][102] =  2.5865462242954268e-17
# sum(weights) =  6.0367136368105826e-05
# proba[102] =  0.0
# theta['t'][102] = [   1.117   -0.363  257.719 -284.2  ] accepted !
# ###########    i =  103
# theta["t"][103]=  [   1.28218575    0.64944282  258.3944181  -283.49401135]
# rapport W_i/c_t =  17.904587433449482
# c_t =  9.722691090319275e-18
# weights['t'][103] =  1.7408077271504173e-16
# sum(weights) =  6.0367136368270185e-05
# proba[103] =  0.0
# theta['t'][103] = [   1.282    0.649  258.394 -283.494] accepted !
# ###########    i =  104
# theta["t"][104]=  [   1.8191464    -0.65475041  258.54073113 -282.38779385]
# rapport W_i/c_t =  8.500861657386308
# c_t =  9.722691090319275e-18
# weights['t'][104] =  8.26512518963066e-17
# sum(weights) =  6.036713636834311e-05
# proba[104] =  0.0
# theta['t'][104] = [   1.819   -0.655  258.541 -282.388] accepted !
# ###########    i =  105
# the prior is O
# ###########    i =  105
# theta["t"][105]=  [   1.13105429   -0.82339748  258.72505125 -283.07989156]
# rapport W_i/c_t =  3.8615897001000805
# c_t =  9.722691090319275e-18
# weights['t'][105] =  3.754504377163173e-17
# sum(weights) =  6.0367136368370934e-05
# proba[105] =  0.0
# theta['t'][105] = [   1.131   -0.823  258.725 -283.08 ] accepted !
# ###########    i =  106
# theta["t"][106]=  [   1.91464101   -0.67114823  257.09433601 -284.74468373]
# rapport W_i/c_t =  10.825177341793909
# c_t =  9.722691090319275e-18
# weights['t'][106] =  1.0524985529218572e-16
# sum(weights) =  6.036713636846646e-05
# proba[106] =  0.0
# theta['t'][106] = [   1.915   -0.671  257.094 -284.745] accepted !
# ###########    i =  107
# theta["t"][107]=  [ 1.19338433e+00 -1.58619412e-01  2.59945153e+02 -2.84158859e+02]
# rapport W_i/c_t =  5.329048380170574
# c_t =  9.722691090319275e-18
# weights['t'][107] =  5.181269120576481e-17
# sum(weights) =  6.036713636850855e-05
# proba[107] =  0.0
# theta['t'][107] = [ 1.19300e+00 -1.59000e-01  2.59945e+02 -2.84159e+02] accepted !
# ###########    i =  108
# the prior is O
# ###########    i =  108
# the prior is O
# ###########    i =  108
# the prior is O
# ###########    i =  108
# the prior is O
# ###########    i =  108
# theta["t"][108]=  [ 1.44849866e+00 -1.26405390e-01  2.59677810e+02 -2.83157491e+02]
# rapport W_i/c_t =  4.938062637890722
# c_t =  9.722691090319275e-18
# weights['t'][108] =  4.801125761285862e-17
# sum(weights) =  6.0367136368546846e-05
# proba[108] =  0.0
# theta['t'][108] = [ 1.44800e+00 -1.26000e-01  2.59678e+02 -2.83157e+02] accepted !
# ###########    i =  109
# theta["t"][109]=  [   1.51794371   -0.33211936  258.55312438 -283.85334636]
# rapport W_i/c_t =  1.6089898734859591
# c_t =  9.722691090319275e-18
# weights['t'][109] =  1.564371150735587e-17
# sum(weights) =  6.036713636855277e-05
# proba[109] =  0.0
# theta['t'][109] = [   1.518   -0.332  258.553 -283.853] accepted !
# ###########    i =  110
# the prior is O
# ###########    i =  110
# theta["t"][110]=  [   1.36712508    0.62927549  257.74331516 -284.70057189]
# rapport W_i/c_t =  24.737072414877993
# c_t =  9.722691090319275e-18
# weights['t'][110] =  2.4051091356871697e-16
# sum(weights) =  6.0367136368783554e-05
# proba[110] =  0.0
# theta['t'][110] = [   1.367    0.629  257.743 -284.701] accepted !
# ###########    i =  111
# theta["t"][111]=  [ 1.21381760e+00  2.40587091e-01  2.58738410e+02 -2.81173509e+02]
# rapport W_i/c_t =  212.91375139991968
# c_t =  9.722691090319275e-18
# weights['t'][111] =  2.070094633742452e-15
# sum(weights) =  6.0367136370843925e-05
# proba[111] =  0.0
# theta['t'][111] = [ 1.21400e+00  2.41000e-01  2.58738e+02 -2.81174e+02] accepted !
# ###########    i =  112
# the prior is O
# ###########    i =  112
# theta["t"][112]=  [   1.45177975   -0.88033358  258.34447905 -284.69788764]
# rapport W_i/c_t =  3.0998194018144587
# c_t =  9.722691090319275e-18
# weights['t'][112] =  3.013858647962026e-17
# sum(weights) =  6.036713637086434e-05
# proba[112] =  0.0
# theta['t'][112] = [   1.452   -0.88   258.344 -284.698] accepted !
# ###########    i =  113
# the prior is O
# ###########    i =  113
# the prior is O
# ###########    i =  113
# theta["t"][113]=  [   1.53938326   -0.75101314  259.33372618 -285.17507363]
# rapport W_i/c_t =  5.497065523329736
# c_t =  9.722691090319275e-18
# weights['t'][113] =  5.3446269986579286e-17
# sum(weights) =  6.036713637090806e-05
# proba[113] =  0.0
# theta['t'][113] = [   1.539   -0.751  259.334 -285.175] accepted !
# ###########    i =  114
# the prior is O
# ###########    i =  114
# theta["t"][114]=  [ 1.78566803e+00 -1.86881526e-01  2.57269500e+02 -2.83357241e+02]
# rapport W_i/c_t =  6.124979466877104
# c_t =  9.722691090319275e-18
# weights['t'][114] =  5.955128329099452e-17
# sum(weights) =  6.036713637095789e-05
# proba[114] =  0.0
# theta['t'][114] = [ 1.78600e+00 -1.87000e-01  2.57269e+02 -2.83357e+02] accepted !
# ###########    i =  115
# theta["t"][115]=  [   1.47674855   -0.58504631  259.73749882 -283.53614466]
# rapport W_i/c_t =  3.71731222921546
# c_t =  9.722691090319275e-18
# weights['t'][115] =  3.6142278490928036e-17
# sum(weights) =  6.036713637098431e-05
# proba[115] =  0.0
# theta['t'][115] = [   1.477   -0.585  259.737 -283.536] accepted !
# ###########    i =  116
# theta["t"][116]=  [   1.10775694   -0.62749517  258.21960749 -283.5994648 ]
# rapport W_i/c_t =  2.309485928403205
# c_t =  9.722691090319275e-18
# weights['t'][116] =  2.2454418259303578e-17
# sum(weights) =  6.036713637099704e-05
# proba[116] =  0.0
# theta['t'][116] = [   1.108   -0.627  258.22  -283.599] accepted !
# ###########    i =  117
# the prior is O
# ###########    i =  117
# the prior is O
# ###########    i =  117
# theta["t"][117]=  [   1.73131222   -0.766658    257.61429119 -284.32703427]
# rapport W_i/c_t =  3.8733143682253757
# c_t =  9.722691090319275e-18
# weights['t'][117] =  3.765903909795049e-17
# sum(weights) =  6.036713637102498e-05
# proba[117] =  0.0
# theta['t'][117] = [   1.731   -0.767  257.614 -284.327] accepted !
# ###########    i =  118
# the prior is O
# ###########    i =  118
# theta["t"][118]=  [   1.46011666   -0.52781288  260.16215578 -283.4933175 ]
# rapport W_i/c_t =  6.670676618161323
# c_t =  9.722691090319275e-18
# weights['t'][118] =  6.48569281217982e-17
# sum(weights) =  6.036713637108011e-05
# proba[118] =  0.0
# theta['t'][118] = [   1.46    -0.528  260.162 -283.493] accepted !
# ###########    i =  119
# theta["t"][119]=  [ 1.35501770e+00 -2.41425061e-01  2.57462899e+02 -2.84721345e+02]
# rapport W_i/c_t =  3.866806564911847
# c_t =  9.722691090319275e-18
# weights['t'][119] =  3.7595765736656496e-17
# sum(weights) =  6.036713637110798e-05
# proba[119] =  0.0
# theta['t'][119] = [ 1.35500e+00 -2.41000e-01  2.57463e+02 -2.84721e+02] accepted !
# ###########    i =  120
# theta["t"][120]=  [   1.27490625   -0.86312272  258.18114308 -284.26130029]
# rapport W_i/c_t =  2.634494011515834
# c_t =  9.722691090319275e-18
# weights['t'][120] =  2.5614371453264486e-17
# sum(weights) =  6.036713637112388e-05
# proba[120] =  0.0
# theta['t'][120] = [   1.275   -0.863  258.181 -284.261] accepted !
# ###########    i =  121
# the prior is O
# ###########    i =  121
# the prior is O
# ###########    i =  121
# the prior is O
# ###########    i =  121
# the prior is O
# ###########    i =  121
# the prior is O
# ###########    i =  121
# theta["t"][121]=  [   1.61726809    0.5154097   258.90883434 -282.7575825 ]
# rapport W_i/c_t =  21.78236717035108
# c_t =  9.722691090319275e-18
# weights['t'][121] =  2.1178322721323552e-16
# sum(weights) =  6.036713637132594e-05
# proba[121] =  0.0
# theta['t'][121] = [   1.617    0.515  258.909 -282.758] accepted !
# ###########    i =  122
# theta["t"][122]=  [ 1.29244831e+00 -7.74291827e-02  2.60089006e+02 -2.82425501e+02]
# rapport W_i/c_t =  22.561706294965763
# c_t =  9.722691090319275e-18
# weights['t'][122] =  2.1936050077646392e-16
# sum(weights) =  6.036713637153558e-05
# proba[122] =  0.0
# theta['t'][122] = [ 1.29200e+00 -7.70000e-02  2.60089e+02 -2.82426e+02] accepted !
# ###########    i =  123
# the prior is O
# ###########    i =  123
# theta["t"][123]=  [   1.23131214   -0.47426753  257.28438446 -284.81265436]
# rapport W_i/c_t =  5.13695107800376
# c_t =  9.722691090319275e-18
# weights['t'][123] =  4.994498847751315e-17
# sum(weights) =  6.0367136371575795e-05
# proba[123] =  0.0
# theta['t'][123] = [   1.231   -0.474  257.284 -284.813] accepted !
# ###########    i =  124
# the prior is O
# ###########    i =  124
# theta["t"][124]=  [ 1.52466141e+00  1.31488465e-01  2.58259117e+02 -2.83718987e+02]
# rapport W_i/c_t =  3.1138992554387186
# c_t =  9.722691090319275e-18
# weights['t'][124] =  3.0275480547005855e-17
# sum(weights) =  6.036713637159635e-05
# proba[124] =  0.0
# theta['t'][124] = [ 1.52500e+00  1.31000e-01  2.58259e+02 -2.83719e+02] accepted !
# ###########    i =  125
# the prior is O
# ###########    i =  125
# theta["t"][125]=  [   1.76060702   -0.68487336  257.98791288 -286.05923559]
# rapport W_i/c_t =  22.3802141965226
# c_t =  9.722691090319275e-18
# weights['t'][125] =  2.1759590916796722e-16
# sum(weights) =  6.036713637180422e-05
# proba[125] =  0.0
# theta['t'][125] = [   1.761   -0.685  257.988 -286.059] accepted !
# ###########    i =  126
# theta["t"][126]=  [ 1.38119187e+00 -1.08725218e-01  2.59609074e+02 -2.85146636e+02]
# rapport W_i/c_t =  6.5161729943625915
# c_t =  9.722691090319275e-18
# weights['t'][126] =  6.335473711526824e-17
# sum(weights) =  6.036713637185786e-05
# proba[126] =  0.0
# theta['t'][126] = [ 1.38100e+00 -1.09000e-01  2.59609e+02 -2.85147e+02] accepted !
# ###########    i =  127
# theta["t"][127]=  [ 1.15396169e+00  7.57166637e-02  2.58079671e+02 -2.82585106e+02]
# rapport W_i/c_t =  8.56956811347895
# c_t =  9.722691090319275e-18
# weights['t'][127] =  8.331926354480593e-17
# sum(weights) =  6.0367136371931454e-05
# proba[127] =  0.0
# ...
# weights['t'][398] =  2.0635508613378788e-17
# sum(weights) =  6.0367137134994834e-05
# proba[398] =  0.0
# theta['t'][398] = [ 1.36500e+00 -1.31000e-01  2.58251e+02 -2.84450e+02] accepted !
# ###########    i =  399
# the prior is O
# ###########    i =  399
# the prior is O
# ###########    i =  399
# theta["t"][399]=  [   1.47422223   -0.52628183  256.55545978 -283.23445971]
# rapport W_i/c_t =  15.023581231534113
# c_t =  9.722691090319275e-18
# weights['t'][399] =  1.460696393845246e-16
# sum(weights) =  6.0367137135131186e-05
# proba[399] =  0.0
# theta['t'][399] = [   1.474   -0.526  256.555 -283.234] accepted !
# ###########    i =  400
# the prior is O
# ###########    i =  400
# theta["t"][400]=  [   1.36821223   -0.93972711  258.89439283 -283.5886366 ]
# rapport W_i/c_t =  3.066027184999534
# c_t =  9.722691090319275e-18
# weights['t'][400] =  2.981003519427166e-17
# sum(weights) =  6.036713713515127e-05
# proba[400] =  0.0
# theta['t'][400] = [   1.368   -0.94   258.894 -283.589] accepted !
# ###########    i =  401
# the prior is O
# ###########    i =  401
# the prior is O
# ###########    i =  401
# the prior is O
# ###########    i =  401
# the prior is O
# ###########    i =  401
# theta["t"][401]=  [ 1.81514288e+00  6.12571596e-02  2.59031998e+02 -2.85019310e+02]
# rapport W_i/c_t =  6.450980709560208
# c_t =  9.722691090319275e-18
# weights['t'][401] =  6.272089266866255e-17
# sum(weights) =  6.036713713520427e-05
# proba[401] =  0.0
# theta['t'][401] = [ 1.81500e+00  6.10000e-02  2.59032e+02 -2.85019e+02] accepted !
# ###########    i =  402
# the prior is O
# ###########    i =  402
# theta["t"][402]=  [   1.13847629   -0.97681918  259.50408896 -282.80033547]
# rapport W_i/c_t =  10.789557005653425
# c_t =  9.722691090319275e-18
# weights['t'][402] =  1.0490352976735847e-16
# sum(weights) =  6.036713713529945e-05
# proba[402] =  0.0
# theta['t'][402] = [   1.138   -0.977  259.504 -282.8  ] accepted !
# ###########    i =  403
# theta["t"][403]=  [   1.45188028   -0.58132395  259.14286797 -284.5845504 ]
# rapport W_i/c_t =  2.335485122617426
# c_t =  9.722691090319275e-18
# weights['t'][403] =  2.2707200393245666e-17
# sum(weights) =  6.036713713531243e-05
# proba[403] =  0.0
# theta['t'][403] = [   1.452   -0.581  259.143 -284.585] accepted !
# ###########    i =  404
# theta["t"][404]=  [   1.61997887   -0.35267857  257.19168506 -284.40216178]
# rapport W_i/c_t =  4.552888983192351
# c_t =  9.722691090319275e-18
# weights['t'][404] =  4.4266333152097055e-17
# sum(weights) =  6.0367137135346976e-05
# proba[404] =  0.0
# theta['t'][404] = [   1.62    -0.353  257.192 -284.402] accepted !
# ###########    i =  405
# theta["t"][405]=  [   1.30971277   -0.8430052   256.48850463 -283.22476387]
# rapport W_i/c_t =  24.667927983973176
# c_t =  9.722691090319275e-18
# weights['t'][405] =  2.398386436264135e-16
# sum(weights) =  6.036713713557709e-05
# proba[405] =  0.0
# theta['t'][405] = [   1.31    -0.843  256.489 -283.225] accepted !
# ###########    i =  406
# the prior is O
# ###########    i =  406
# theta["t"][406]=  [   1.41749349   -0.2861328   257.59323237 -283.82214955]
# rapport W_i/c_t =  2.5284456614949047
# c_t =  9.722691090319275e-18
# weights['t'][406] =  2.4583296105372933e-17
# sum(weights) =  6.036713713559195e-05
# proba[406] =  0.0
# theta['t'][406] = [   1.417   -0.286  257.593 -283.822] accepted !
# ###########    i =  407
# theta["t"][407]=  [   1.75432981   -0.79139734  257.65574858 -283.23318428]
# rapport W_i/c_t =  4.987738441172929
# c_t =  9.722691090319275e-18
# weights['t'][407] =  4.849424010283498e-17
# sum(weights) =  6.0367137135630725e-05
# proba[407] =  0.0
# theta['t'][407] = [   1.754   -0.791  257.656 -283.233] accepted !
# ###########    i =  408
# theta["t"][408]=  [   1.2266758     0.5886489   259.42697969 -282.82210889]
# rapport W_i/c_t =  36.935348768482605
# c_t =  9.722691090319275e-18
# weights['t'][408] =  3.591109863891608e-16
# sum(weights) =  6.0367137135980116e-05
# proba[408] =  0.0
# theta['t'][408] = [   1.227    0.589  259.427 -282.822] accepted !
# ###########    i =  409
# theta["t"][409]=  [   1.39328215   -0.72647975  258.82618265 -283.92036588]
# rapport W_i/c_t =  1.944634646302802
# c_t =  9.722691090319275e-18
# weights['t'][409] =  1.8907081949534426e-17
# sum(weights) =  6.03671371359893e-05
# proba[409] =  0.0
# theta['t'][409] = [   1.393   -0.726  258.826 -283.92 ] accepted !
# ###########    i =  410
# the prior is O
# ###########    i =  410
# the prior is O
# ###########    i =  410
# the prior is O
# ###########    i =  410
# the prior is O
# ###########    i =  410
# the prior is O
# ###########    i =  410
# the prior is O
# ###########    i =  410
# the prior is O
# ###########    i =  410
# theta["t"][410]=  [ 1.41469442e+00 -1.01703152e-02  2.59306049e+02 -2.84794695e+02]
# rapport W_i/c_t =  4.008205636260539
# c_t =  9.722691090319275e-18
# weights['t'][410] =  3.897054522783784e-17
# sum(weights) =  6.0367137136018544e-05
# proba[410] =  0.0
# theta['t'][410] = [ 1.41500e+00 -1.00000e-02  2.59306e+02 -2.84795e+02] accepted !
# ###########    i =  411
# theta["t"][411]=  [   1.25313653   -0.6722916   260.59517767 -284.1662222 ]
# rapport W_i/c_t =  15.56760178032446
# c_t =  9.722691090319275e-18
# weights['t'][411] =  1.5135898312719912e-16
# sum(weights) =  6.036713713616018e-05
# proba[411] =  0.0
# theta['t'][411] = [   1.253   -0.672  260.595 -284.166] accepted !
# ###########    i =  412
# the prior is O
# ###########    i =  412
# the prior is O
# ###########    i =  412
# the prior is O
# ###########    i =  412
# theta["t"][412]=  [ 1.60898004e+00  3.30283602e-02  2.58532696e+02 -2.84444853e+02]
# rapport W_i/c_t =  2.7706632214582507
# c_t =  9.722691090319275e-18
# weights['t'][412] =  2.6938302617547434e-17
# sum(weights) =  6.03671371361774e-05
# proba[412] =  0.0
# theta['t'][412] = [ 1.60900e+00  3.30000e-02  2.58533e+02 -2.84445e+02] accepted !
# ###########    i =  413
# the prior is O
# ###########    i =  413
# the prior is O
# ###########    i =  413
# theta["t"][413]=  [ 1.19739716e+00  9.48519033e-02  2.58545930e+02 -2.83393383e+02]
# rapport W_i/c_t =  3.4346068595816868
# c_t =  9.722691090319275e-18
# weights['t'][413] =  3.339362151240433e-17
# sum(weights) =  6.036713713620107e-05
# proba[413] =  0.0
# theta['t'][413] = [ 1.19700e+00  9.50000e-02  2.58546e+02 -2.83393e+02] accepted !
# ###########    i =  414
# the prior is O
# ###########    i =  414
# theta["t"][414]=  [ 1.38984077e+00 -1.16849222e-01  2.59588762e+02 -2.82604098e+02]
# rapport W_i/c_t =  8.34936601103619
# c_t =  9.722691090319275e-18
# weights['t'][414] =  8.117830652531616e-17
# sum(weights) =  6.0367137136272525e-05
# proba[414] =  0.0
# theta['t'][414] = [ 1.39000e+00 -1.17000e-01  2.59589e+02 -2.82604e+02] accepted !
# ###########    i =  415
# theta["t"][415]=  [   1.32164148   -0.35224752  258.73324497 -282.05028543]
# rapport W_i/c_t =  10.500123826666382
# c_t =  9.722691090319275e-18
# weights['t'][415] =  1.0208946037677837e-16
# sum(weights) =  6.036713713636489e-05
# proba[415] =  0.0
# theta['t'][415] = [   1.322   -0.352  258.733 -282.05 ] accepted !
# ###########    i =  416
# the prior is O
# ###########    i =  416
# the prior is O
# ###########    i =  416
# theta["t"][416]=  [ 1.82839793e+00  1.79103484e-01  2.58930931e+02 -2.83612943e+02]
# rapport W_i/c_t =  5.106527270695004
# c_t =  9.722691090319275e-18
# weights['t'][416] =  4.9649187197258716e-17
# sum(weights) =  6.036713713640482e-05
# proba[416] =  0.0
# theta['t'][416] = [ 1.82800e+00  1.79000e-01  2.58931e+02 -2.83613e+02] accepted !
# ###########    i =  417
# theta["t"][417]=  [   1.51859759   -0.83887054  258.68012563 -283.28858887]
# rapport W_i/c_t =  2.87677509365132
# c_t =  9.722691090319275e-18
# weights['t'][417] =  2.7969995571896086e-17
# sum(weights) =  6.036713713642307e-05
# proba[417] =  0.0
# theta['t'][417] = [   1.519   -0.839  258.68  -283.289] accepted !
# ###########    i =  418
# theta["t"][418]=  [   1.83398839   -0.72480957  258.50374192 -284.38583187]
# rapport W_i/c_t =  2.8410156758078458
# c_t =  9.722691090319275e-18
# weights['t'][418] =  2.7622317798634335e-17
# sum(weights) =  6.036713713644096e-05
# proba[418] =  0.0
# theta['t'][418] = [   1.834   -0.725  258.504 -284.386] accepted !
# ###########    i =  419
# the prior is O
# ###########    i =  419
# theta["t"][419]=  [ 1.73602841e+00 -6.64761404e-02  2.60055423e+02 -2.83313950e+02]
# rapport W_i/c_t =  9.566729920874797
# c_t =  9.722691090319275e-18
# weights['t'][419] =  9.30143597651802e-17
# sum(weights) =  6.036713713652426e-05
# proba[419] =  0.0
# theta['t'][419] = [ 1.73600e+00 -6.60000e-02  2.60055e+02 -2.83314e+02] accepted !
# ###########    i =  420
# theta["t"][420]=  [   1.44767609   -0.46087528  259.09265376 -282.38695826]
# rapport W_i/c_t =  6.477320438863861
# c_t =  9.722691090319275e-18
# weights['t'][420] =  6.29769857200846e-17
# sum(weights) =  6.036713713657751e-05
# proba[420] =  0.0
# theta['t'][420] = [   1.448   -0.461  259.093 -282.387] accepted !
# ###########    i =  421
# theta["t"][421]=  [   1.96987901   -0.31888575  257.2523251  -284.70248116]
# rapport W_i/c_t =  8.53508439090309
# c_t =  9.722691090319275e-18
# weights['t'][421] =  8.298398896255659e-17
# sum(weights) =  6.036713713665077e-05
# proba[421] =  0.0
# theta['t'][421] = [   1.97    -0.319  257.252 -284.702] accepted !
# ###########    i =  422
# theta["t"][422]=  [   1.62942344   -0.81930021  259.07710346 -285.08729711]
# rapport W_i/c_t =  4.914657989498976
# c_t =  9.722691090319275e-18
# weights['t'][422] =  4.7783701446468134e-17
# sum(weights) =  6.036713713668883e-05
# proba[422] =  0.0
# theta['t'][422] = [   1.629   -0.819  259.077 -285.087] accepted !
# ###########    i =  423
# the prior is O
# ###########    i =  423
# theta["t"][423]=  [ 1.37265889e+00 -1.02465611e-02  2.59160182e+02 -2.82269846e+02]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/onyxia/work/Projet-Monte-Carlo/28-04-24.ipynb Cell 23 line 5
#      <a href='vscode-notebook-cell://user-fdexchamps-216332-0.user.lab.sspcloud.fr/home/onyxia/work/Projet-Monte-Carlo/28-04-24.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=50'>51</a> print(f'theta["t"][{i}]= ',theta['t'][i])
#      <a href='vscode-notebook-cell://user-fdexchamps-216332-0.user.lab.sspcloud.fr/home/onyxia/work/Projet-Monte-Carlo/28-04-24.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=52'>53</a> # Update the weight of theta_i :
# ---> <a href='vscode-notebook-cell://user-fdexchamps-216332-0.user.lab.sspcloud.fr/home/onyxia/work/Projet-Monte-Carlo/28-04-24.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=53'>54</a> weights['t'][i] = (K((S(y)-S(x[i]))/epsilon,(epsilon**2)*sigma_hat)/epsilon)*prior_density(theta['t'][i])/M_t(N,theta['t'][i],theta['t-1'],weights['t-1'])
#      <a href='vscode-notebook-cell://user-fdexchamps-216332-0.user.lab.sspcloud.fr/home/onyxia/work/Projet-Monte-Carlo/28-04-24.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=55'>56</a> # Draw uniformly a random value between 0 and 1 :
#      <a href='vscode-notebook-cell://user-fdexchamps-216332-0.user.lab.sspcloud.fr/home/onyxia/work/Projet-Monte-Carlo/28-04-24.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=57'>58</a> u = np.random.uniform(low=0, high=1)
#
# /home/onyxia/work/Projet-Monte-Carlo/28-04-24.ipynb Cell 23 line 4
#       <a href='vscode-notebook-cell://user-fdexchamps-216332-0.user.lab.sspcloud.fr/home/onyxia/work/Projet-Monte-Carlo/28-04-24.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> def M_t(N,theta_i,theta_prev, weights_prev) :
#       <a href='vscode-notebook-cell://user-fdexchamps-216332-0.user.lab.sspcloud.fr/home/onyxia/work/Projet-Monte-Carlo/28-04-24.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     # defines the mutation kernel M_t as the weighted sum of densities
# ----> <a href='vscode-notebook-cell://user-fdexchamps-216332-0.user.lab.sspcloud.fr/home/onyxia/work/Projet-Monte-Carlo/28-04-24.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     densities = np.array([ psi(theta_i, theta_prev[i]) for i in range(N)])
#       <a href='vscode-notebook-cell://user-fdexchamps-216332-0.user.lab.sspcloud.fr/home/onyxia/work/Projet-Monte-Carlo/28-04-24.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     return np.sum(weights_prev*densities)
#
# /home/onyxia/work/Projet-Monte-Carlo/28-04-24.ipynb Cell 23 line 4
#       <a href='vscode-notebook-cell://user-fdexchamps-216332-0.user.lab.sspcloud.fr/home/onyxia/work/Projet-Monte-Carlo/28-04-24.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> def M_t(N,theta_i,theta_prev, weights_prev) :
#       <a href='vscode-notebook-cell://user-fdexchamps-216332-0.user.lab.sspcloud.fr/home/onyxia/work/Projet-Monte-Carlo/28-04-24.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     # defines the mutation kernel M_t as the weighted sum of densities
# ----> <a href='vscode-notebook-cell://user-fdexchamps-216332-0.user.lab.sspcloud.fr/home/onyxia/work/Projet-Monte-Carlo/28-04-24.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     densities = np.array([ psi(theta_i, theta_prev[i]) for i in range(N)])
#       <a href='vscode-notebook-cell://user-fdexchamps-216332-0.user.lab.sspcloud.fr/home/onyxia/work/Projet-Monte-Carlo/28-04-24.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     return np.sum(weights_prev*densities)
#
# /home/onyxia/work/Projet-Monte-Carlo/28-04-24.ipynb Cell 23 line 3
#       <a href='vscode-notebook-cell://user-fdexchamps-216332-0.user.lab.sspcloud.fr/home/onyxia/work/Projet-Monte-Carlo/28-04-24.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> def psi(y, x, covariance = np.diag([0.25,0.25,1,1])):
#       <a href='vscode-notebook-cell://user-fdexchamps-216332-0.user.lab.sspcloud.fr/home/onyxia/work/Projet-Monte-Carlo/28-04-24.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     # Define smoothing kernel using a Gaussian kernel with estimated covariance
# ----> <a href='vscode-notebook-cell://user-fdexchamps-216332-0.user.lab.sspcloud.fr/home/onyxia/work/Projet-Monte-Carlo/28-04-24.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     return multivariate_normal.pdf(y, mean=x, cov=covariance)
#
# File /opt/mamba/lib/python3.11/site-packages/scipy/stats/_multivariate.py:584, in multivariate_normal_gen.pdf(self, x, mean, cov, allow_singular)
#     565 def pdf(self, x, mean=None, cov=1, allow_singular=False):
#     566     """Multivariate normal probability density function.
#     567
#     568     Parameters
#    (...)
#     582
#     583     """
# --> 584     params = self._process_parameters(mean, cov, allow_singular)
#     585     dim, mean, cov_object = params
#     586     x = self._process_quantiles(x, dim)
#
# File /opt/mamba/lib/python3.11/site-packages/scipy/stats/_multivariate.py:421, in multivariate_normal_gen._process_parameters(self, mean, cov, allow_singular)
#     414 dim, mean, cov = self._process_parameters_psd(None, mean, cov)
#     415 # After input validation, some methods then processed the arrays
#     416 # with a `_PSD` object and used that to perform computation.
#     417 # To avoid branching statements in each method depending on whether
#     418 # `cov` is an array or `Covariance` object, we always process the
#     419 # array with `_PSD`, and then use wrapper that satisfies the
#     420 # `Covariance` interface, `CovViaPSD`.
# --> 421 psd = _PSD(cov, allow_singular=allow_singular)
#     422 cov_object = _covariance.CovViaPSD(psd)
#     423 return dim, mean, cov_object
#
# File /opt/mamba/lib/python3.11/site-packages/scipy/stats/_multivariate.py:185, in _PSD.__init__(self, M, cond, rcond, lower, check_finite, allow_singular)
#     183 self.rank = len(d)
#     184 self.U = U
# --> 185 self.log_pdet = np.sum(np.log(d))
#     187 # Initialize attributes to be lazily computed.
#     188 self._pinv = None
#
# File /opt/mamba/lib/python3.11/site-packages/numpy/core/fromnumeric.py:2313, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2310         return out
#    2311     return res
# -> 2313 return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2314                       initial=initial, where=where)
#
# File /opt/mamba/lib/python3.11/site-packages/numpy/core/fromnumeric.py:88, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85         else:
#      86             return reduction(axis=axis, out=out, **passkwargs)
# ---> 88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# Nous avons rencontrer plusieurs difficultés qui pourraient être la cause de résultats non optimaux de notre implémentation du SMC sampler :
# - nous n'étions pas sûr que la forme exacte du noyau K
# - de même la forme exacte de $\pi_{LF}(\theta|y)$ n'était pas clair, et cela malgré la consultation de l'article :On sequential Monte Carlo, partial rejection control and approximate Bayesian computation" de G. W. Peters, Y. Fan et S. A. Sisson (November 11, 2009) où ils disent que l'on peut en calculer la forme exacte. Comme ils disent que P = 1 dans l'estimation de
# $\pi_{LF}(\theta|y)$ par une somme de 1 à P nous avons donc dit que $\pi_{LF}(\theta|y)\propto \pi(x)\pi(y|x,\theta) $
# - autre source possible d'erreur/ralentissement du code : les valeurs prisent par $K_{\epsilon}(\frac{S(y)-S(y)}{\epsilon})/\epsilon$ sont très petites, typiquement $10^{-15}$ par exemple, cela multiplie sans doutes les approximations et autres erreurs de calcul.
# - enfin l'étape de resampling déjà mentionnée plus haut, ce qui nous a paru étranges c'est qu'il faut re-sampler (sans remises) N valeurs  en accord avec les poids mais dans une liste de N valeurs, donc on reprend juste toute la liste... Et puis quand bien même ce serait un tirage avec remise, mettre les poids à 1/N entraîne que le $\theta^0_i$ est rejeté à chaque fois car sont poids est trop faible du fait de la def de $\pi_{LF}(\theta|y)$ retenue.
